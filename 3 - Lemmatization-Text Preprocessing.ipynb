# %% [markdown]
# ### Wordnet Lemmatizer
#
# Lemmatization technique is like stemming. The output we will get after lemmatization is called
# 'lemma', which is a root word rather than root stem, the output of stemming. After lemmatization,
# we will be getting a valid word that means the same thing.
#
# NLTK provides WordNetLemmatizer class which is a thin wrapper around the wordnet corpus. This
# class uses morphy() function to the WordNet CorpusReader class to find a lemma. Let us
# understand it with an example -
#
# #### Usecases
# 1. Q&A
# 2. Chatbot
# 3. Text Summerization

# %%
import nltk
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Win\AppData\Roaming\nltk_data...

# %%
lemmatizer = WordNetLemmatizer()

# %%
'''
POStags:
Noun-n
adjective-a
verb - v
adverb - r
'''
lemmatizer.lemmatize("going",pos='v'),lemmatizer.lemmatize("going",pos='a') #press Shift+tab on lemmatize for details like POStag(pos)
# Out:
# ('go', 'going')

# %%
words =["eating","eaten","going","gone","writes","written","programming"]

# %%
for word in words:
    print(word+"--->"+lemmatizer.lemmatize(word,pos='v'))
# Out:
# eating--->eat
# eaten--->eat
# going--->go
# gone--->go
# writes--->write
# written--->write
# programming--->program
