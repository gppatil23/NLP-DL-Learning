# %%
#Random Information
paragraph = '''
Kalam was the youngest of four brothers and a sister in the family. 
His ancestors had been wealthy Marakayar traders and landowners, with numerous properties and
large tracts of land. Marakayar are a Muslim ethnic group found in coastal Tamil Nadu and Sri 
Lanka who claim descent from Arab traders and local women. The family business had involved 
trading goods and transporting passengers between the Indian mainland and the Pamban Island 
and to and from Sri Lanka. With the opening of the Pamban Bridge connecting Pamban Island 
to mainland India in 1914, the businesses failed. As a result, apart from the ancestral home, 
the other family fortune and properties were lost by the 1920s, and the family was poverty-stricken
by the time Kalam was born. As a young boy, he delivered newspapers to support the family's meager income.
Kalam worked with metallurgist V. S. R. Arunachalam, who was then scientific adviser to the Defence Minister, 
on the suggestion by the then Defence Minister R. Venkataraman on the simultaneous development of a quiver of 
missiles instead of taking planned missiles one after another. Venkatraman was instrumental in getting the cabinet
approval for allocating ₹3.88 billion (equivalent to ₹66 billion or US$680 million in 2023) for the project 
titled Integrated Guided Missile Development Programme (IGMDP) and appointed Kalam as its chief executive.'''

# %% [markdown]
# ## Difference between Porterstemmer, Snowballstemmer and WordNetLemmatizer

# %%
from nltk.stem import PorterStemmer

# %%
from nltk.corpus import stopwords

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Win\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopwords.words('english')  #list of stopwords
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  'shouldn',
#  "shouldn't",
#  "should've",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  'were',
#  'weren',
#  "weren't",
#  "we've",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  'your',
#  "you're",
#  'yours',
#  'yourself',
#  'yourselves',
#  "you've"]

# %%
stemmer = PorterStemmer()

# %%
sentences = nltk.sent_tokenize(paragraph)

# %%
sentences
# Out:
# ['\nKalam was the youngest of four brothers and a sister in the family.',
#  'His ancestors had been wealthy Marakayar traders and landowners, with numerous properties and\nlarge tracts of land.',
#  'Marakayar are a Muslim ethnic group found in coastal Tamil Nadu and Sri \nLanka who claim descent from Arab traders and local women.',
#  'The family business had involved \ntrading goods and transporting passengers between the Indian mainland and the Pamban Island \nand to and from Sri Lanka.',
#  'With the opening of the Pamban Bridge connecting Pamban Island \nto mainland India in 1914, the businesses failed.',
#  'As a result, apart from the ancestral home, \nthe other family fortune and properties were lost by the 1920s, and the family was poverty-stricken\nby the time Kalam was born.',
#  "As a young boy, he delivered newspapers to support the family's meager income.",
#  'Kalam worked with metallurgist V. S. R. Arunachalam, who was then scientific adviser to the Defence Minister, \non the suggestion by the then Defence Minister R. Venkataraman on the simultaneous development of a quiver of \nmissiles instead of taking planned missiles one after another.',
#  'Venkatraman was instrumental in getting the cabinet\napproval for allocating ₹3.88 billion (equivalent to ₹66 billion or US$680 million in 2023) for the project \ntitled Integrated Guided Missile Development Programme (IGMDP) and appointed Kalam as its chief executive.']

# %%
type(sentences)
# Out:
# list

# %%
## apply stopwords and filter and then apply stemming
for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])
    words = [stemmer.stem(word) for word in words if word not in set(stopwords.words('english'))]
    sentences[i] = " ".join(words) #converting all the words into sentences

# %%
sentences
# Out:
# ['kalam youngest four brother sister famili .',
#  'hi ancestor wealthi marakayar trader landown , numer properti larg tract land .',
#  'marakayar muslim ethnic group found coastal tamil nadu sri lanka claim descent arab trader local women .',
#  'the famili busi involv trade good transport passeng indian mainland pamban island sri lanka .',
#  'with open pamban bridg connect pamban island mainland india 1914 , busi fail .',
#  'as result , apart ancestr home , famili fortun properti lost 1920 , famili poverty-stricken time kalam born .',
#  "as young boy , deliv newspap support famili 's meager incom .",
#  'kalam work metallurgist v. s. r. arunachalam , scientif advis defenc minist , suggest defenc minist r. venkataraman simultan develop quiver missil instead take plan missil one anoth .',
#  'venkatraman instrument get cabinet approv alloc ₹3.88 billion ( equival ₹66 billion us $ 680 million 2023 ) project titl integr guid missil develop programm ( igmdp ) appoint kalam chief execut .']

# %%
from nltk.stem import SnowballStemmer
snowballstemmer = SnowballStemmer('english')

# %%
sentences = nltk.sent_tokenize(paragraph)

# %%
for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])
    words = [snowballstemmer.stem(word) for word in words if word not in set(stopwords.words('english'))]
    sentences[i] = " ".join(words) #converting all the words into sentences

# %%
sentences
# Out:
# ['kalam youngest four brother sister famili .',
#  'his ancestor wealthi marakayar trader landown , numer properti larg tract land .',
#  'marakayar muslim ethnic group found coastal tamil nadu sri lanka claim descent arab trader local women .',
#  'the famili busi involv trade good transport passeng indian mainland pamban island sri lanka .',
#  'with open pamban bridg connect pamban island mainland india 1914 , busi fail .',
#  'as result , apart ancestr home , famili fortun properti lost 1920s , famili poverty-stricken time kalam born .',
#  "as young boy , deliv newspap support famili 's meager incom .",
#  'kalam work metallurgist v. s. r. arunachalam , scientif advis defenc minist , suggest defenc minist r. venkataraman simultan develop quiver missil instead take plan missil one anoth .',
#  'venkatraman instrument get cabinet approv alloc ₹3.88 billion ( equival ₹66 billion us $ 680 million 2023 ) project titl integr guid missil develop programm ( igmdp ) appoint kalam chief execut .']

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
sentences = nltk.sent_tokenize(paragraph)

# %%
for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])
    words = [lemmatizer.lemmatize(word.lower(),pos='v') for word in words if word not in set(stopwords.words('english'))]
    sentences[i] = " ".join(words) #converting all the words into sentences

# %%
sentences
# Out:
# ['kalam youngest four brothers sister family .',
#  'his ancestors wealthy marakayar traders landowners , numerous properties large tracts land .',
#  'marakayar muslim ethnic group find coastal tamil nadu sri lanka claim descent arab traders local women .',
#  'the family business involve trade goods transport passengers indian mainland pamban island sri lanka .',
#  'with open pamban bridge connect pamban island mainland india 1914 , businesses fail .',
#  'as result , apart ancestral home , family fortune properties lose 1920s , family poverty-stricken time kalam bear .',
#  "as young boy , deliver newspapers support family 's meager income .",
#  'kalam work metallurgist v. s. r. arunachalam , scientific adviser defence minister , suggestion defence minister r. venkataraman simultaneous development quiver missiles instead take plan missiles one another .',
#  'venkatraman instrumental get cabinet approval allocate ₹3.88 billion ( equivalent ₹66 billion us $ 680 million 2023 ) project title integrate guide missile development programme ( igmdp ) appoint kalam chief executive .']
